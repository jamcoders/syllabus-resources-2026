# %% [markdown]
# # JamCoders Day 1 Lecture 2
#
# ### Boaz Barak

# %% [markdown]
# ## Components of Python programs:
#
# * __Variables:__ storing data of types `int`, `str`, `float`, `list`,...
#
# * __Operations:__ `+`, `*`  , ...
#
# * __Control flow:__ Decide when to execute instructions: `if`, `while`,....

# %% [markdown]
# # Riddle

# %%
# What will be printed?
print(2+4)
print("2"+"4")
print("2+4")

# %% [markdown]
# # Operations (integral types)

# %%
# Python things can be combined using arithmetic operators
print(1 + 1)

# %%
# The result of arithmetic operations can be assigned to variables
x = 10 - 5.3
y=5
z=x+y
print(z)

# %%
# The result of an arithmetic operation WILL NOT CHANGE the variable contents
print(x)

# %%
# To change the value of a variable, we assign to it a new value
x = x * 2
print(x)

# %%
# An example of floating point division
print(4.3 / 2.0)

# %%
# Another example
print(5 / 2)

# %%
# If we want this to be an integer, we can do either
z1 = 5 // 2 # integer division
z2 = int( 5 / 2 ) # first divide then translate to int
# (the same for positive numbers)
print(z1)
print(z2)

# %%
# An example of "modulus" or "mod" or "finding the remainder"
morning_lecture = 9
afternoon_lecture = morning_lecture + 5 
print( afternoon_lecture , afternoon_lecture % 12 )

# %%
# What is the answer?
print( 8 % 3 )

# %%
# How about now?
print( 10 % 4 )

# %%
# How about now?
print( 10 % 2 )

# %%
# And now?
print( 143 % 5 )

# %%
x = 1
x = x + 1
print(x)

# %%
x = 1
x += 1 # This is equivalent to "x = x + 1"
print(x)

# %%
x = 10
x -= 5
print(x)

# %%
x = 60
x *= 50
print(x)

# %%
x = 100
x /= 10
print(x, type(x))

# %%
x = 100
x //= 10
print(x , type(x))

# %% [markdown]
# # Example

# %%
seconds_in_minute = 60
minutes_in_hours = 60
hours_in_day = 24
days_in_year = 365

seconds_in_year = seconds_in_minute * minutes_in_hours * hours_in_day * days_in_year
print(seconds_in_year)

# %%
age = 16+(6/12)
print(f"You've been alive for {age*seconds_in_year:,} seconds")

# %%
names = [] 
ages = []

# %%
for i in []:
    name = names[i]
    age = ages[i]
    print(f"{name} has been alive for {age*seconds_in_year:,} seconds")

# %% [markdown]
# ## Difference between `=` and `==`
#
# `x = 5`: Assign the value `5` to the variable `x`
#
# `x==5`: Is `True` if `x` equals to `5` already and is `False` otherwise

# %%
x = 8
x = 5
print(x)
print(x=5)

# %%
x = 8
x == 5
print(x)
print(x==5)

# %%
print(7 == x)

# %%
print( 7 = x )

# %%
# Order of operations matters!
# *, /, % happen first, in the order they appear
print( 1 + 3 * 5,  (1+3)*5 )

# %% [markdown]
# # Operations (boolean types)

# %%
x = (12 > 7)
print(f"x is variable of type {type(x)} and its value is {x}")

# %%
x = (5 < 3)
if x == True:
    print("x is True")

# %%
# Booleans can be combined using logical ands
# The result of logical and is True if and only if both sides are True

print( (12 > 7) and (3 > 8) )

# %%
# Booleans can be combined using logical ors
# The result of logical or is True if either side is True

print( (12 > 7) or (3 > 8) )

# %%
# Logical negation changes True to False
print( not (2*4 == 8) )

# %%
# and False to True
print( not False )

# %% [markdown]
# # Operations (string, list)

# %%
# Adding strings is called "concatenation"
x = 'Hello ' + 'world!'
print(x)

# %%
# Adding list is also called "concatenation"
x = [1,7,8, 2] + [2]
print(x)

# %%
# A one element list is not the same as a single number
x = [7]
y = 7
print(x==y)
print(f"x[0] = {x[0]}")

# %%
print(f"y[0]= {y[0]}")

# %%
# Aside: can you have a 0-element list?
print( len([]) )

# %%
x = [2]
y = [3]
print(x + y)

# %% [markdown]
# # Errors

# %%
# Errors occur when something you do that isn't allowed
# Remember: True is supposed to be capitalized!
print(true)

# %%
del boaz

# %%
# Variables must be assigned before being used
print(boaz)

# %%
# Once you assign a variable you can use it
boaz = 7
print(boaz)

# %%
# Dividing by 0 is undefined and thus an error in Python
1 / 0

# %% [markdown]
# # Issues to watch out for

# %% [markdown]
# Different types of parenthesis `(`,`)` .. `[`,`]` ... `{`,`}`

# %%
L = [1,2,3] # list
print(L[1])

# %%
print( L(1) )

# %%
print( L{1} )

# %%
# order of operations
print(  (2+3)*4 , 2+3*4 )

# %%
# track changes in variables
x = 10
y = x
x = 12
print(f"x={x}, y={y}")

# %% [markdown]
# # if, for, while

# %%
x = 7
if x < 8:
    print("***")
else:
    print("xxx")

# %%
i = 0
while i < 5:
    print(i)
    i = i + 1

# %%
for i in range(5):
    print(i)

# %%
print("hello", end=" ")
print("world")

# %%
tic_tac_toe = [".",".",".",
               ".",".",".",
               ".",".","."]

for row in range(3):
    for column in range(3):
        print(tic_tac_toe[3*row + column], end=" ")
    print()

# %% [markdown]
# # Extra

# %%
# List indexing and slicing
my_list = [ "hello", "world", "this", "is", "boaz"]

# %%
print( len(my_list) )

# %%
print( my_list[2] )

# %%
print( my_list[2:4] )

# %%
print ( my_list[-1] )
