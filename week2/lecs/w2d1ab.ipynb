# %%
# %config InteractiveShell.ast_node_interactivity="none"

# %% [markdown]
# ## How to trace through your code
#
# ## How to execute code line by line
#
# ## How to figure out a question your stuck on

# %%
# Remember how loops over strings work
# What happens here?
def loopInFunction2(x):
    for i in range(len(x)):
        print(i*2+x[i:])
    print('Loop completed!')

loopInFunction2('5637291done')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 8
#       4     for i in range(len(x)):
#       5         print(i*2+x[i:])
#       6     print('Loop completed!')
#       7
# ----> 8 loopInFunction2('5637291done')
#
# Cell In[14], line 5, in loopInFunction2(x)
#       3 def loopInFunction2(x):
#       4     for i in range(len(x)):
# ----> 5         print(i*2+x[i:])
#       6     print('Loop completed!')
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# # Error messages are very important. They tell you
#
# ## 1. Where in your code there is a problem and
# ## 2. What type of problem exists.
# ### In this case, I was trying to add a variable which is an intiger type to one that is a string type. If I traced my code line by line, I may have caught the error before running the code.
#
# ### For the code in the next cell, write out what its output will be using pen and paper. But don't just write out the final answer. Write out the intermediate steps. For example,
#
# ### What is x?
# ### What is len(x)?
# ### What is range(len(x))?
# ### What values does i iterate over?
# ### What is str(i*2)?
# ### What is x[i:]?
# ### What is str(i*2)+x[i:]?
#
# ### Write out these values for each value that i iterates over. That is, trace through the code <span style="color:red">DO NOT rush to write out the final answer without writing out the values above for each value of i and tracing through the code line by line. </span>

# %%
# Remember how loops over strings work
# What happens here?
def loopInFunction2(x):
    for i in range(len(x)):
        print(str(i*2)+x[i:])
    print('Loop completed!')

loopInFunction2('5637291done')
# Out:
# 05637291done
# 2637291done
# 437291done
# 67291done
# 8291done
# 1091done
# 121done
# 14done
# 16one
# 18ne
# 20e
# Loop completed!

# %% [markdown]
# ### The most important thing you'll learn in this program is how to think logically and slowly and sequentially work through a problem. <span style="color:red">DO NOT rush to write out the final answer or write python code without going through the following steps</span>.
#
# ## Step 1: Read the question:
# ### This might sound obvious but you need to read and re-read the question a few times to make sure you understand what it is asking.
# ## Step 2:
# ### Run a small example: Have a few scenarios and write out what the question should answer in those scenarios. Think about how you would approach the problem for those few examples.
# ## Step 3:
# ### Write pseudo code: Once you've done step 2, for a small example, think about how you can generalize it for the problem you were given. After you have thought about your approach and potentially even said it out loud, write out your logic in pseudo code. Pseudo code is a combination of English and code but the important thing here is to write out how you would approach the problem.
# ## Step 4:
# ### Translate pseudo code to python. Translate your pseudo code from Step 3 to python code.

# %% [markdown]
# ## Now go through steps 1 to 4 to perform the following task.
# ### Write a function find_min which takes in a list as input, and returns the minimum number in the list as output.

# %% [markdown]
# ## Step1: Have you read the question multiple time to understand what it is asking?
# ## Step2: What are the small examples you are running?
# ### We might want examples where the minimum element in the list is the first element in the list,
#
#
# ### Examples where the minimum is in the middle
# L1=[3,1,0,200,1,1]
# L2=[0,-10,3]
#
#
# ### Examples where there list contains multiple elements with the same value
# L1=[0,2,2,4]
# L2=[2,2,2]
#
#
# ### Examples where the input is an empty list,
# L=[]
#
# ### Examples where the minimum is a positive number and in the middle of the list
#
# L4=[5,3,1,200]
#
#
# ### Examples where the list only has one value
# L3=[1]
#
# ### Write out what the output of find_min should be for each of these examples. What is the logic for finding this minimum? Think about it without writing code.

# %% [markdown]
# ### We need to go through each element in the list and check whether this element is the minimum one we have seen so far. To do that, we need to keep track of the minimum elelement we have seen thus far. Variables are how we store things, and loops are how we iterate over lists. So my pseudo code looks something like this.
#
# ### min_var=first element of input list.
# ### For each element in the input list:
# ### &ensp;&ensp;&ensp;&ensp;if element is less than min_var:
# ###  &ensp;&ensp;&ensp;&ensp; &ensp;&ensp; min_var now takes on element
# ### return min_var

# %%
def find_min(L):
    current_min=L[0]
    for x in L:   #--->x iterating over list 
        if x<current_min:
            current_min=x
    return current_min
L1=[3,1,-5,200,1,1]
L2=[]
L3=[1]
L4=[5,3,1,200]
L5=[2,2,4]
print(find_min(L2))

#What happens when I have print(find_min(L2))? What do I need to change to fix the issue?
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[5], line 12
#       8 L2=[]
#       9 L3=[1]
#      10 L4=[5,3,1,200]
#      11 L5=[2,2,4]
# ---> 12 print(find_min(L2))
#      13
#      14 #What happens when I have print(find_min(L2))? What do I need to change to fix the issue?
#
# Cell In[5], line 2, in find_min(L)
#       1 def find_min(L):
# ----> 2     current_min=L[0]
#       3     for x in L:   #--->x iterating over list
#       4         if x<current_min:
#       5             current_min=x
#
# IndexError: list index out of range

# %%
def find_min(lst):
    if lst==[]:            #---->Check if list is empty
        print("List is empty")#----->print that list is empty
        return             #--->return without ding anything else
    i=0 
    current_min=lst[0]
    while i<len(lst):
        if current_min>lst[i]:
            current_min=lst[i]
        i+=1
    return current_min
L1=[3,1,-5,200,1,1]
L2=[]
L3=[1]
L4=[5,3,1,200]
L5=[2,2,4]
print(find_min(L2))
# Out:
# List is empty
# None

# %% [markdown]
# This is a student code that we went through together. In my question I didn't tell you that the input
# list was an integer. So this student handeled edge cases:
# 1. When the list is empty
# 2. When the list doesn't consist of all numbers
#
# The way to find out which edge cases you should handle is by thinking through good examples where your code could fail,
# like the lists L2, L6 and L7 in the next cell.

# %%
def find_min(L):
    num_L=[]
    if L==[]:      #----->Same thing we checked earlier, check whether list is empty
         print("List empty")  #---->If list isn't empty print that the list is empty
    for i in L:                              # This bit of code checks each element in the list and adds it to a new list if its a number
        if type(i)==int or type(i)==float:   #########
            num_L.append(i)                  ########
    if num_L==[]:                            # This bit of code checks whether the new list is empty, meaning the input list had no numbers
        print("No numbers found")            # If the new list is empty we print that no numbers were found
    else:
        mini=num_L[0]                        #Otherwise, we iterate through the new list, which now only has numbers and do the same thing 
        for i in num_L:                      #we did before, track the minimum value in a variable called mini, and update mini if the 
            if mini>i:                       #current element as we're iterating through the new list is less than the variable. 
                mini=i
    return mini                              #After we're done iterating through the new list, the minimum value is mini

#These are examples designed to test a whole bunch of edge cases. This is why coming up with good examples is important. 
#If you don't come up with good examples, then you don't catch the edge cases that your code should handle. 
L1=[3,1,-5,200,1,1]
L2=[]                 
L3=[1]
L4=[5,3,1,200]
L5=[2,2,4]
L6=['apple', 3, 'banana']
L7=['apple', 'banana', 'orange']
print(find_min(L6))   #---->What happens if I input L2, L6 or L7?
# Out:
# 3

# %% [markdown]
# What is wrong with the student code above?

# %%
def find_min(L):
    num_L=[]
    if L==[]:      #----->Same thing we checked earlier, check whether list is empty
         print("List empty")  #---->If list isn't empty print that the list is empty
    for i in L:                              # This bit of code checks each element in the list and adds it to a new list if its a number
        if type(i)==int or type(i)==float:   #########
            num_L.append(i)                  ########
    if num_L==[]:                            # This bit of code checks whether the new list is empty, meaning the input list had no numbers
        print("No numbers found")            # If the new list is empty we print that no numbers were found
    else:
        mini=num_L[0]                        #Otherwise, we iterate through the new list, which now only has numbers and do the same thing 
        for i in num_L:                      #we did before, track the minimum value in a variable called mini, and update mini if the 
            if mini>i:                       #current element as we're iterating through the new list is less than the variable. 
                mini=i
    return mini                              #After we're done iterating through the new list, the minimum value is mini

#These are examples designed to test a whole bunch of edge cases. This is why coming up with good examples is important. 
#If you don't come up with good examples, then you don't catch the edge cases that your code should handle. 
L1=[3,1,-5,200,1,1]
L2=[]                 
L3=[1]
L4=[5,3,1,200]
L5=[2,2,4]
L6=['apple', 3, 'banana']
L7=['apple', 'banana', 'orange']
print(find_min(L2))   #---->What happens if I input L2, L6 or L7?
# Out:
# List empty
# No numbers found
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[10], line 26
#      22 L4=[5,3,1,200]
#      23 L5=[2,2,4]
#      24 L6=['apple', 3, 'banana']
#      25 L7=['apple', 'banana', 'orange']
# ---> 26 print(find_min(L2))   #---->What happens if I input L2, L6 or L7?
#
# Cell In[10], line 15, in find_min(L)
#      11         mini=num_L[0]                        #Otherwise, we iterate through the new list, which now only has numbers and do the same thing
#      12         for i in num_L:                      #we did before, track the minimum value in a variable called mini, and update mini if the
#      13             if mini>i:                       #current element as we're iterating through the new list is less than the variable.
#      14                 mini=i
# ...

# %% [markdown]
# Although the code tried to handle the edge case by checking for an empty list or a list that doesn't have numbers,
# the only thing it does in that case is print a string saying what the problem is. The function doesn't return anything,
# so the function doesn't stop running. In order to do that, we have to add a return function.

# %%
def find_min(L):
    num_L=[]
    if L==[]:      #----->Same thing we checked earlier, check whether list is empty
         print("List empty")  #---->If list isn't empty print that the list is empty
         return #---->We added this now so that the rest of the lines aren't executed
    for i in L:                              # This bit of code checks each element in the list and adds it to a new list if its a number
        if type(i)==int or type(i)==float:   #########
            num_L.append(i)                  ########
    if num_L==[]:                            # This bit of code checks whether the new list is empty, meaning the input list had no numbers
        print("No numbers found")            # If the new list is empty we print that no numbers were found
        return #---->We added this now so that the rest of the lines aren't executed
    else:
        mini=num_L[0]                        #Otherwise, we iterate through the new list, which now only has numbers and do the same thing 
        for i in num_L:                      #we did before, track the minimum value in a variable called mini, and update mini if the 
            if mini>i:                       #current element as we're iterating through the new list is less than the variable. 
                mini=i
    return mini                              #After we're done iterating through the new list, the minimum value is mini

#These are examples designed to test a whole bunch of edge cases. This is why coming up with good examples is important. 
#If you don't come up with good examples, then you don't catch the edge cases that your code should handle. 
L1=[3,1,-5,200,1,1]
L2=[]                 
L3=[1]
L4=[5,3,1,200]
L5=[2,2,4]
L6=['apple', 3, 'banana']
L7=['apple', 'banana', 'orange']
print(find_min(L2))   #---->What happens if I input L2, L6 or L7?
# Out:
# List empty
# None

# %% [markdown]
# Can you create the same find_min function using a while loop instead of a for loop?

# %% [markdown]
# Just like before, we need a variable to keep track of the minimum element so far.
# Just like before, we need to iterate over the list and compare the current element of the list to the minimum variable thus far.
# But now, the only format we can have is<br />
# while SOMETHING IS TRUE:&ensp;&ensp;----->What would you be checking for here?<br />
# &ensp;&ensp;&ensp;&ensp;&ensp;&ensp;Do Something&ensp;&ensp;----->What do you do here?

# %%
def find_min(L):
    if len(L)==0:   #---->Check if the list is empty, same as when we used the for loop.
        return         
    current_min=L[0]#---->same as when we used the for loop 
    i=0          
    while i<len(L):   
        #We are iterating over the indices of the list, which go from 0 up to the length of the list-1  
        #For example, if L is [5,3,1,200], we want i to be 0,1,2,3. We want to stop the loop when i is 4 
        #because we don't want to attempt to get the 5th element of a list with only 4 elements. 
        if L[i]<current_min:
            current_min=L[i]  
            #This if statement is the same as when we used a for loop iterating over the list indices.
        i+=1   
        #This is new to the while loop. While the for loops we used were automatically incrementing, 
        #here, we need to manually increment the index to go to the next value. 
    return current_min  #--->This part is the same. 
L1=[3,1,-5,200,1,1]
L2=[]   #
L3=[1]
L4=[5,3,1,200]
L5=[2,2,4]
print(find_min(L5))
# Out:
# 2

# %%
#Another solutino
def find_min(lst):
    if lst==[]:
        print("List empty")
        return
    i=0
    current_min=lst[0]
    while i<len(lst):
        if current_min>lst[i]:
            current_min=lst[i]
        i+=1
    return current_min
L1=[3,1,-5,200,1,1]
L2=[]
L3=[1]
L4=[5,3,1,200]
L5=[2,2,4]
print(find_min(L2))
# Out:
# List empty
# None
