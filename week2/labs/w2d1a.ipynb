# %% [markdown]
# ![Reminder to Save](https://github.com/jamcoders/jamcoders-public-2025/blob/main/images/warning.png?raw=true)

# %%
# %config InteractiveShell.ast_node_interactivity="none"
import sys
if 'google.colab' in sys.modules:
    # %pip install --force-reinstall git+https://github.com/jamcoders/jamcoders-public-2026.git --quiet
from jamcoders.base_utils import *

# %% [markdown]
# # Week 2, Day 1A, Review of Essentials

# %% [markdown]
# ## 0. Python Tracing - ```for``` and ```while``` loops!

# %% [markdown]
# We can always run Python code to see what it does, but it's often very helpful to know what it will do just by reading it.
#
# For the following questions, you should read the Python code and determine what will happen **without running the code**.
#
# **Trace the code on paper** and determine what gets printed for the following examples.

# %% [markdown]
# ### 0.1

# %% [markdown]
# What is printed after ```mystery1(["welcome", "to", "jamcoders", "week", 2])``` is called?

# %% [markdown]
# ```python
# def mystery1(lst):
#     for val in lst:
#         print(val)
# ```

# %% [markdown]
# ### 0.2

# %% [markdown]
# What is printed after ```mystery2([1, 2, 3, 4, 5])``` is called?

# %% [markdown]
# ```python
# def mystery2(lst):
#     for i in range(len(lst)):
#         print(i)
#         lst[i] = lst[i] + 1
#         print(lst)
# ```

# %% [markdown]
# ### 0.3

# %% [markdown]
# What is printed after ```mystery3(3)``` is called?

# %% [markdown]
# ```python
# def mystery3(x):
#     i = 0
#     while i < x * 2:
#         print("hi!")
#         i = i + 1
#     print("bye!")
# ```

# %% [markdown]
# ### 0.4

# %% [markdown]
# What is printed after ```mystery4([["hello", "woah", "you", "are", "cool!"],
#     ["sorry", "this", "is", "tedious"],
#     ["you", "are", "doing", "great!"]])``` is called?

# %% [markdown]
# ```python
#
# def mystery4(lst):
#     for x in lst:
#         print("starting with", x)
#         for y in x:
#             print(y)
#         print("done with", x)
# ```

# %% [markdown]
# ### 🛑 Before you move on! 🛑
#
# ✋ Raise your hand and check your work with a TA! ✋

# %% [markdown]
# ## 1. List Indexing

# %% [markdown]
# ### List indexing review (expand to read)

# %% [markdown]
# List elements can be accessed using *indices*. Each element of the list has a corresponding *index* that starts at 0 for the first element, 1 for the second element, etc.
#
# For example, in the list `fruits = ['mango', 'pineapple', 'orange', 'soursop']`, the indices are as follows:
#
# |  **Index**  |  **0**  |    **1**    |   **2**  |   **3**   |
# |:-----------:|:-------:|:-----------:|:--------:|:---------:|
# | **Element** | 'mango' | 'pineapple' | 'orange' | 'soursop' |
#
# Each element can then be accessed like this: `list_name[item_index]`
#
# For example, to access the first element of `'fruits'` which is `'mango'`, you can use `fruits[0]` which returns `'mango'`. If you want to print `'mango'`, you can say `print(fruits[0])` which will print the result: `'mango'`.

# %% [markdown]
# ### 1.1
# **Lists** can be created like this:
# `list_name = [item1, item2, item3, item4]`
#
# Create a list called `multiples_of_five` that contains the integers 5, 10, 15, 20, and 25 in that order.

# %%
# Your code here

# %% [markdown]
# ### 1.2
# Print the first element in `multiples_of_five`.

# %%
# Your solution here

# %% [markdown]
# ### 1.3
# Remember from previous labs that you can use negative indices for lists. Print the second to last element in `multiples_of_five` using negative indices.

# %%
# Your solution here

# %% [markdown]
# ### 1.4
# As a final exercise, print the third element in the list ```multiples_of_five```.

# %%
# Your solution here

# %% [markdown]
# ## 2. List Slicing

# %% [markdown]
# ### List slicing review (expand to read)

# %% [markdown]
# When accessing elements from a list using indexes, it is possible to produce a sub-list, containing elements from a specific range of indexes within the list. This is done using list **slicing**.
#
# It takes the form: `list_name[index_of_the_first_element_you_want:index_of_the_last_element_you_want_plus_one]`.
#
# **For example:**
#
# In the list `fruits = ['mango', 'pineapple', 'orange', 'soursop']`, if you want a sublist that contains _the second to third elements_ of the list, you could do this by accessing the relevant indices that follow the form above. Remember that the indices of the list are:
#
# |  **Index**  |  **0**  |    **1**    |   **2**  |   **3**   |
# |:-----------:|:-------:|:-----------:|:--------:|:---------:|
# | **Element** | 'mango' | 'pineapple' | 'orange' | 'soursop' |
#
# In order to access the desired sublist (_the second to third elements_), we can enter the relevant indices while considering the format given above. We can do this is as follows:
#
# `fruits[1:3] => ['pineapple', 'orange']`
#
# <br>
#
# **Note** that the indices on either side of the colon are optional. When one of these is absent, it means the sublist will start or end at the actual start or end of the main list.
# - In other words, if the left index is absent, the sublist will automatically start at index 0.
#
#     `fruits[:2] => ['mango', 'pineapple']`
# <br>
#
# - If the right index is absent, the sublist will automatically end at the last index.
#
#     `fruits[1:] => ['pineapple', 'orange', 'soursop']`
#
# - If both indices are absent, the sublist will be a copy of the original list.
#
#     `fruits[:] => ['mango', 'pineapple', 'orange', 'soursop']`

# %% [markdown]
# ### 2.1
# Print a sliced list which includes the first three elements of `multiples_of_five` created in 1.1 above.

# %%
# Your solution here

# should print out [5,10,15]

# %% [markdown]
# ### 2.2
# Print a sliced list of `multiples_of_five` which includes its second, third, and fourth elements.

# %%
# Your solution here

# should print out [10, 15, 20]

# %% [markdown]
# ### 2.3
# Print a sliced list of `multiples_of_five` which includes its third element only.

# %%
# Your solution here

# should print out [15]

# %% [markdown]
# ### 2.4
# Print a sliced list of `multiples_of_five` which includes everything <i>after</i> the first element.

# %%
# Your solution here

# should print out [10, 15, 20, 25]

# %% [markdown]
# ### 2.5
# Print a sliced list of `multiples_of_five` which includes the first, third, and fifth element.

# %%
# Your solution here

# should print out [5, 15, 25]

# %% [markdown]
# ## 3. Appending to a List

# %% [markdown]
# ###Appending to a list review (expand to read)

# %% [markdown]
# When you have a list, you can add an item to the end of the list using the `append()` method. It can be used like this:
#
# `list_name.append(item_to_be_added)`

# %% [markdown]
# ### 3.1
# Append the next multiple of 5 to the list `multiples_of_five`.

# %%
# Your solution here

# To test your solution we can print the list
print(multiples_of_five)

# %%
# This tests your solution
assert_equal(got=multiples_of_five, want=[5,10,15,20,25,30], )

# %% [markdown]
# ## 4. Reversing a List

# %% [markdown]
# ### 4.1
# Create an empty list (a list that contains no elements) called `descending_multiples`.

# %%
# Your solution here

# %% [markdown]
# ### 4.2
# Append the value `30` to `descending_multiples`.

# %%
# Your solution here

# %% [markdown]
# ### 4.3
# Using a for loop, append all the other elements from `multiples_of_five` to `descending_multiples`. Start from the end of the `multiples_of_five` list and iterate backwards so that `descending_multiples` contains the elements, in reverse order.
#
# Hint: First create a variable called `length` that stores the length of `multiples_of_five`. Use this value within your for loop.
#
# Note: You may need to re-run 4.1 and 4.2 while testing your code.

# %%
# Your solution here

# %%
# This tests your solution
assert_equal(got=descending_multiples, want=[30, 25, 20, 15, 10, 5])

# %% [markdown]
# ### 4.4
# Write a function called `reverse_list` that takes in a list `lst` and returns the reversed list.
#
# **Ex:** `reverse_list([1, 2, 3, 4]) => [4, 3, 2, 1]`
#
# You can do this using a combination of for loops and indexing.

# %%
def reverse_list(lst):
    # Your solution here
    # Remember to return (not print) the reversed list!

# %%
# This tests your solution
assert_equal(got=reverse_list(descending_multiples), want=[5, 10, 15, 20, 25, 30])
assert_equal(got=reverse_list([6]), want=[6])
assert_equal(got=reverse_list([0,3,-9]), want=[-9,3,0])

# %% [markdown]
# ### More List Slicing!
# When reversing a list it is common to find a modified approach to list slicing. Recall from question 2 that list slcing returns a sublist, there is a third parameter (step) that changes the order of the list. Negative numbers reverse the list while integers allow you to skip over some elements!
#
# `Sub_Lst = Lst[Start : End + 1 : Step]`
#
#
# `Lst = [1, 2, 3, 4, 5]`
#
# `Lst[::-1] => [5, 4, 3, 2, 1]`
#
# `Lst[::2] => [1, 3, 5]`              *indeces  [0, 2, 4]*
#
# `Lst[::-2] => [5, 3, 1]`             *indeces  [-1, -3, -5]*

# %% [markdown]
# ### 4.5
# Write a function called `reverse_list_slice` that takes in a list `lst` and returns the reversed list using list slicing.
#
# **Ex:** `reverse_list_slice([1, 2, 3, 4]) => [4, 3, 2, 1]`

# %%
def reverse_list_slice(lst):
    # Your solution here

# This tests your solution
assert_equal(got=reverse_list_slice([6]), want=[6])
assert_equal(got=reverse_list_slice([10, 9, 8, 7]), want=[7, 8, 9, 10])
assert_equal(got=reverse_list_slice([-4, 3, -2, 1]), want=[1, -2, 3, -4])

# %% [markdown]
# ### 4.6
# Write a function called `every_other` that takes a list and returns every other element using list slicing.
#
# *Eg*. `every_other([5, 10, 15, 20, 25, 30]) => [5, 15, 25]`

# %%
def every_other(lst):
    # Your solution here

# This tests your solution
assert_equal(got=every_other([6]), want=[6])
assert_equal(got=every_other([10, 9, 8, 7]), want=[10, 8])
assert_equal(got=every_other([-4, 3, -2, 1]), want=[-4, -2])

# %% [markdown]
# ### 4.7
# Write a function called `reverse_two` that returns a two element list containing the last two elements of `descending_multiples` in reverse order.
#
# **Ex:** `reverse_two([1, 2, 3, 4]) ==> [4, 3]`
#
# *Hint: Remeber that your list slices __before__ your stop index*

# %%
def reverse_two(lst):
    # Your solution here
    # Remember to return (not print) the final list!

# %%
# This tests your solution
assert_equal(got=reverse_two(descending_multiples), want=[5, 10])
assert_equal(got=reverse_two([1, 2, 3, 4, 5, 6, 7, 8]), want=[8, 7])
assert_equal(got=reverse_two([7, 77, 777, 7777, 77777]), want=[77777, 7777])

# %% [markdown]
# ## 5. Ready, *SET*, go!

# %% [markdown]
# ### 5.1
# Write a function `in_the_list` that takes in a list `lst` and a target element `target` that returns `True` if `target` is in `lst` and `False` otherwise. **Use a `for` loop.**

# %%
def in_the_list(lst, target):
    # Your solution here
    # Remember to return (not print) the answer!

# %%
# This tests your solution
my_playlist = ["protoje", "chronixx", "koffee", "sevana", "bobmarley"]

# Do you listen to the artist who gave a founding donation for JamCoders?
has_early_donor = in_the_list(my_playlist, "chronixx")

assert_equal(got=has_early_donor, want=True)
assert_equal(got=in_the_list(my_playlist, "gaga"), want=False)

# %% [markdown]
# ### 5.2
# Write a function `has_overlaps` which takes in two lists, `lst1` and `lst2`, and returns `True` if any element from `lst1` is also in `lst2` and `False` otherwise. **You can do this using `for` loops. Use your `in_the_list` function**.

# %%
def has_overlaps(lst1, lst2):
    # Your code here
    # Remember to return (not print) the answer!

# %% [markdown]
# Test your code's output by running the below code. You're at the plant store and want to know if they have fertilzer for any of the plants in your garden.

# %%
# This tests your solution
plant_store = ['hibiscus', 'rose', 'orchid', 'bouganvillea']
my_garden = ['hibiscus', 'bouganvillea', 'hydrangea']
spice_garden = ['balck pepper', 'cinnamon', 'vanilla']

assert_equal(got=has_overlaps(plant_store, my_garden), want=True)
assert_equal(got=has_overlaps(spice_garden, my_garden), want=False)
assert_equal(got=has_overlaps(spice_garden, []), want=False)

# %% [markdown]
# ### 5.3
# Write a function called `intersection` which takes in two lists, `lst1` and `lst2`, and returns a list containing all the elements present in both lists.  **Use a `for` loop once and use your `in_the_list` function**.

# %%
def intersection(lst1, lst2):
    # Write your code here
    # Remember to return (not print) the answer!

# %%
# This tests your solution
assert_equal(got=intersection([1, 2, 3], [2, 3, 4]), want=[2, 3])
assert_equal(got=intersection([1, 2, 3], []), want=[])
assert_equal(got=intersection([1,2,3,4,5,6,7], [5,6,7,8,9,10]), want=[5,6,7])

# %% [markdown]
# ### 5.4
# Can you rewrite the ```intersection``` function using <b>nested loops</b> and <i>without</i> calling the ```in_the_list``` function?

# %%
def intersection(lst1, lst2):
    # Write your code here
    # Remember to return (not print) the answer!

# %%
# This tests your solution
assert_equal(got=intersection([1, 2, 3], [2, 3, 4]), want=[2, 3])
assert_equal(got=intersection([1, 2, 3], []), want=[])
assert_equal(got=intersection([1,2,3,4,5,6,7], [5,6,7,8,9,10]), want=[5,6,7])
